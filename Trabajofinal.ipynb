# %%
import pandas as pd

# Cargar el dataset
df = pd.read_csv('../../datos/student_habits.csv')

# Crear variable objetivo: exam_score
df["exam_score"] = (df["study_hours_per_day"] > 6).astype(int)

df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.describe(include='all')
# Out:
#        student_id        age  gender  study_hours_per_day  social_media_hours  \
# count        1000  1000.0000    1000           1000.00000         1000.000000
# unique       1000        NaN       3                  NaN                 NaN
# top         S1999        NaN  Female                  NaN                 NaN
# freq            1        NaN     481                  NaN                 NaN
# mean          NaN    20.4980     NaN              3.55010            2.505500
# std           NaN     2.3081     NaN              1.46889            1.172422
# min           NaN    17.0000     NaN              0.00000            0.000000
# 25%           NaN    18.7500     NaN              2.60000            1.700000
# 50%           NaN    20.0000     NaN              3.50000            2.500000
# 75%           NaN    23.0000     NaN              4.50000            3.300000
# max           NaN    24.0000     NaN              8.30000            7.200000
#
# ...

# %%
df['study_hours_per_day'].value_counts().plot(kind='bar', color='skyblue')
plt.title('hora 1')
plt.xlabel('hora 2')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 df['study_hours_per_day'].value_counts().plot(kind='bar', color='skyblue')
# ----> 2 plt.title('hora 1')
#       3 plt.xlabel('hora 2')
#       4 plt.ylabel('Frecuencia')
#
# NameError: name 'plt' is not defined
